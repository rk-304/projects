# %%
#!pip install tweepy 
import tweepy
import json 
import datetime
import pandas as pd

# %%
consumer_key = "x"
consumer_secret = "x"
access_token = "x"
access_token_secret = "x"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True) # authentication

# %%
# all  users in a list
users = ['@GretaThunberg', '@Greenpeace', '@Fridays4future', '@UNFCCC', '@ClimateReality', '@WeDontHaveTime', '@GreenAllianceUK', '@ClimateRealists']

# %%
df_accounts = pd.DataFrame(
    [
 status._json, 
 status.created_at, status.entities, status.lang, 
 status.retweet_count, status.retweeted,
 
 status.user.created_at,
 status.user.description,
 status.user.favourites_count,
 status.user.follow,
 status.user.followers_count,
 status.user.friends_count,
 status.user.id_str, #userid
 status.id_str,
 status.user.location,
 status.user.name,
 status.user.screen_name   
    ]
    for user in users 
    for status in tweepy.Cursor(api.user_timeline, screen_name=user, tweet_mode="extended").items(10000)) #items per account 75000
df_accounts.columns = [
'tweet _json', 
 'tweet created_at', 'tweet entities',  'tweet lang',
 'tweet retweet_count', 'tweet retweeted',

 'created_at',
 'description',
 'favourites_count',
 'follow',
 'followers_count',
 'friends_count',
 'id_str',
 'status.id_str - tweet id?',
 'location',
 'name',
 'screen_name'
] #user and author is same, user contains all relevant information

# %%
df_accounts
# Out:
#                                           tweet _json    tweet created_at  \
# 0   {'created_at': 'Fri Mar 26 13:28:53 +0000 2021... 2021-03-26 13:28:53
# 1   {'created_at': 'Fri Mar 26 13:28:49 +0000 2021... 2021-03-26 13:28:49
# 2   {'created_at': 'Fri Mar 26 13:40:46 +0000 2021... 2021-03-26 13:40:46
# 3   {'created_at': 'Fri Mar 26 13:05:15 +0000 2021... 2021-03-26 13:05:15
# 4   {'created_at': 'Fri Mar 26 13:41:19 +0000 2021... 2021-03-26 13:41:19
# 5   {'created_at': 'Fri Mar 26 13:37:18 +0000 2021... 2021-03-26 13:37:18
# 6   {'created_at': 'Fri Mar 26 12:43:04 +0000 2021... 2021-03-26 12:43:04
# 7   {'created_at': 'Fri Mar 26 12:00:49 +0000 2021... 2021-03-26 12:00:49
# 8   {'created_at': 'Fri Mar 26 13:48:08 +0000 2021... 2021-03-26 13:48:08
# 9   {'created_at': 'Fri Mar 26 13:47:40 +0000 2021... 2021-03-26 13:47:40
# 10  {'created_at': 'Fri Mar 26 10:53:51 +0000 2021... 2021-03-26 10:53:51
# 11  {'created_at': 'Fri Mar 26 10:47:19 +0000 2021... 2021-03-26 10:47:19
# ...

# %%
# Out:
# '1374965184020774918'

# %%
for user in users:
    for status in tweepy.Cursor(api.user_timeline, screen_name=user, tweet_mode="extended").items(1):
#        print(status.user)
        break
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
# ...

# %%
df_user = pd.DataFrame(
    [
 status.user.name
    ]
    for user in users 
    for status in tweepy.Cursor(api.user_timeline, screen_name=user, tweet_mode="extended").items(1)) #items per account 75000
df_user.columns = [
 'name'
] #user and author is same, user contains all relevant information

# %%
dir(status.user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
# ...

# %%
df_accounts.to_json(r'accounts.json')

df_accounts.to_excel('accounts.xlsx')

# %%
hashtags = ['ClimateChange', 'FridayForFuture', 'ClimateStrike', 'ClimateEmergency', 'TheParisAgreement', 'GlobalWarming']

# %%
hashtags = ['ClimateChange', 'FridayForFuture', 'ClimateStrike', 'ClimateEmergency', 'TheParisAgreement', 'GlobalWarming']
df_hashtags = pd.DataFrame(columns=['author', 'text', 'created_at', 'language', 'user', 'retweet_count', 'favorite_count'])

for hashtag in hashtags:
    print(hashtag)
    for tweet in tweepy.Cursor(api.search, q=hashtag).items(1):
        df_hashtags.loc[len(df_hastags)] = [tweet.author.screen_name, tweet.text, tweet.created_at, tweet.lang, tweet.user, tweet.retweet_count, tweet.favorite_count]
# Out:
# ClimateChange
# FridayForFuture
# ClimateStrike
# ClimateEmergency
# TheParisAgreement
# GlobalWarming

# %%
#df_hashtags.to_json(r'hashtags.json')
df_hashtags.to_excel('hashtags.xlsx')

# %%
hashtags = ['ClimateChange', 'FridayForFuture', 'ClimateStrike', 'ClimateEmergency', 'TheParisAgreement', 'GlobalWarming']

# %%
df_hashtags = pd.DataFrame(columns=['author', 'text', 'created_at', 'language', 'user', 'retweet_count', 'favorite_count'])

for hashtag in hashtags:
    print(hashtag)
    for tweet in tweepy.Cursor(api.search, q = hashtag).items(2):
        df_hashtags.loc[len(df_hashtags)] = [tweet.author.screen_name, tweet.text, tweet.created_at, tweet.lang, tweet.user, tweet.retweet_count, tweet.favorite_count]
# Out:
# ClimateChange
# FridayForFuture
# ClimateStrike
# ClimateEmergency
# TheParisAgreement
# GlobalWarming

# %%
for tweet in tweepy.Cursor(api.search, q = 'ClimateChange').items(1): #items per account 75000
    jsonhashtag = json.dumps(tweet._json)

# %%
type(jsonhashtag
# Out:
# str

# %%
f = open("dict.json","w")
f.write(jsonhashtag)
f.close()

# %%
type(jsonhashtag)
# Out:
# str

# %%
jsonhashtag = json.loads(jsonhashtag)

# %%
jsonhashtag
# Out:
# {'created_at': 'Wed Mar 31 13:32:07 +0000 2021',
#  'id': 1377252367431835649,
#  'id_str': '1377252367431835649',
#  'text': 'The latest The Homesteading Guide Daily! https://t.co/mrXxpy9xve Thanks to @SlowwCo @Giacomo_Cortes #climatechange #forests',
#  'truncated': False,
#  'entities': {'hashtags': [{'text': 'climatechange', 'indices': [100, 114]},
#    {'text': 'forests', 'indices': [115, 123]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'SlowwCo',
#     'name': 'Sloww',
#     'id': 4650850093,
#     'id_str': '4650850093',
#     'indices': [75, 83]},
#    {'screen_name': 'Giacomo_Cortes',
#     'name': 'GiacomoCortesOfficial',
#     'id': 1220282883228753921,
#     'id_str': '1220282883228753921',
#     'indices': [84, 99]}],
#   'urls': [{'url': 'https://t.co/mrXxpy9xve',
#     'expanded_url': 'https://paper.li/Homesteadings/1321684095?edition_id=7ad75630-9225-11eb-956d-fa163e65ae25',
#     'display_url': 'paper.li/Homesteadings/…',
# ...

# %%
df_hashtags.to_json(r'hashtags.json')

# %%
dir(df_hashtags.loc[1,0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
# ...

# %%
df_hashtags
#df_hashtags.to_json(r'hashtags.json')
# Out:
#                                                    0
# 0  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 1  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 2  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 3  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 4  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 5  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 6  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 7  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 8  Status(_api=<tweepy.api.API object at 0x7fbd9e...
# 9  Status(_api=<tweepy.api.API object at 0x7fbd9e...

# %%
df_hashtags = pd.DataFrame(
    [

 tweet.created_at,
 tweet.entities,
 tweet.id_str,
 tweet.lang,
 tweet.retweet_count,
 tweet.text,
 tweet.user,

        
 tweet.user.created_at,
 tweet.user.favourites_count,
 tweet.user.followers_count,
 tweet.user.following,
 tweet.user.friends_count,
 tweet.user.id_str,
 tweet.user.lang,
 tweet.user.name,
 tweet.user.screen_name,
 tweet.user.statuses_count
        
    ]
    for hashtag in hashtags 
    for tweet in tweepy.Cursor(api.search, q = hashtag).items(2)) #items per account 75000
df_hashtags.columns = [
 
 'created_at',
 'entities',
 'id_str',
 'lang',
 'retweet_count',
 'text',
 'user',
    
    
    
 'created_at',
 'favourites_count',
 'followers_count',
 'following',
 'friends_count',
 'id_str',
 'lang',
 'name',
 'screen_name',
 'statuses_count'
 
] #user and author is same, user contains all relevant information

# %%
df_hashtags
# Out:
#            created_at                                           entities  \
# 0 2021-03-26 13:55:46  {'hashtags': [{'text': 'climatechange', 'indic...
# 1 2021-03-26 13:55:44  {'hashtags': [{'text': 'ClimateChange', 'indic...
# 2 2021-03-26 13:55:25  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3 2021-03-26 13:55:24  {'hashtags': [{'text': 'SuezBLOCKED', 'indices...
# 4 2021-03-26 13:55:43  {'hashtags': [{'text': 'ClimateStrike', 'indic...
# 5 2021-03-26 13:54:21  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6 2021-03-26 13:55:54  {'hashtags': [{'text': 'twitter', 'indices': [...
# 7 2021-03-26 13:55:54  {'hashtags': [{'text': 'CEEBill', 'indices': [...
# 8 2021-03-26 13:54:39  {'hashtags': [{'text': 'JMDNewsFLASH', 'indice...
# 9 2021-03-26 13:52:26  {'hashtags': [{'text': 'selfcare', 'indices': ...
#
#                 id_str lang  retweet_count  \
# 0  1375446379439480834   en              1
# 1  1375446371851976707   en              0
# ...

# %%
dir(tweet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
#  'source_url',
# ...

# %%
tweet.user.__class__
# Out:
# tweepy.models.User

# %%
t = [
 tweet.user.created_at,
 tweet.user.favourites_count,
 tweet.user.followers_count,
 tweet.user.following,
 tweet.user.friends_count,
 tweet.user.id_str,
 tweet.user.lang,
 tweet.user.name,
 tweet.user.screen_name,
 tweet.user.statuses_count,
    ]

# %%
df_test = pd.DataFrame([t])

# %%
df_test = pd.DataFrame(
    [
 tweet.user.created_at,
 tweet.user.favourites_count,
 tweet.user.followers_count,
 tweet.user.following,
 tweet.user.friends_count,
 tweet.user.id_str,
 tweet.user.lang,
 tweet.user.name,
 tweet.user.screen_name,
 tweet.user.statuses_count
    ])

# %%
df_test.columns = [
 
 'created_at',
 'favourites_count',
 'followers_count',
 'following',
 'friends_count',
 'id_str',
 'lang',
 'name',
 'screen_name',
 'statuses_count'
]

# %%
tweet.user.__str__
# Out:
# method-wrapper

# %%
df_test
# Out:
#            created_at  favourites_count  followers_count  following  \
# 0 2010-07-11 09:26:57               449               53      False
#
#    friends_count     id_str  lang          name screen_name  statuses_count
# 0             86  165352643  None  Andreas Frey      a_frey             645

# %%
df_test.to_excel('test.xlsx')

# %%
 '__class__',
 '__delattr__',
 '__dict__',
 '__dir__',
 '__doc__',
 '__eq__',
 '__format__',
 '__ge__',
 '__getattribute__',
 '__getstate__',
 '__gt__',
 '__hash__',
 '__init__',
 '__init_subclass__',
 '__le__',
 '__lt__',
 '__module__',
 '__ne__',
 '__new__',
 '__reduce__',
 '__reduce_ex__',
 '__repr__',
 '__setattr__',
 '__sizeof__',
 '__str__',
 '__subclasshook__',
 '__weakref__',
 '_api',
 '_json',
 'contributors_enabled',
 'created_at',
 'default_profile',
 'default_profile_image',
 'description',
 'entities',
 'favourites_count',
 'follow',
 'follow_request_sent',
 'followers',
 'followers_count',
 'followers_ids',
 'following',
 'friends',
 'friends_count',
 'geo_enabled',
 'has_extended_profile',
 'id',
 'id_str',
 'is_translation_enabled',
 'is_translator',
 'lang',
 'listed_count',
 'lists',
 'lists_memberships',
 'lists_subscriptions',
 'location',
 'name',
 'notifications',
 'parse',
 'parse_list',
 'profile_background_color',
 'profile_background_image_url',
 'profile_background_image_url_https',
 'profile_background_tile',
 'profile_image_url',
 'profile_image_url_https',
 'profile_link_color',
 'profile_sidebar_border_color',
 'profile_sidebar_fill_color',
 'profile_text_color',
 'profile_use_background_image',
 'protected',
 'screen_name',
 'statuses_count',
 'time_zone',
 'timeline',
 'translator_type',
 'unfollow',
 'url',
 'utc_offset',
 'verified',

# %%
df_hashtags
# Out:
#            created_at                                           entities  \
# 0 2021-03-25 20:25:24  {'hashtags': [{'text': 'ClimateChange', 'indic...
# 1 2021-03-25 20:24:47  {'hashtags': [{'text': 'vaccines', 'indices': ...
# 2 2021-03-25 20:24:17  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3 2021-03-25 20:22:27  {'hashtags': [{'text': 'SuezBLOCKED', 'indices...
# 4 2021-03-25 20:24:44  {'hashtags': [], 'symbols': [], 'user_mentions...
# 5 2021-03-25 20:24:03  {'hashtags': [{'text': 'JustíciaClimàtica', 'i...
# 6 2021-03-25 20:25:55  {'hashtags': [{'text': 'publiclands', 'indices...
# 7 2021-03-25 20:24:44  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8 2021-03-25 20:24:04  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9 2021-03-25 20:23:26  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                 id_str lang  retweet_count  \
# 0  1375182048906907653   en              1
# 1  1375181891243012097   en              1
# ...
